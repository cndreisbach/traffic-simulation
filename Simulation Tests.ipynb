# %%
import traffic.simulation as sim
import traffic.car as simcar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import imp

# %%
imp.reload(sim)
imp.reload(simcar)
# Out:
# <module 'traffic.car' from '/Users/clinton/src/github.com/cndreisbach/traffic-simulation/traffic/car.py'>

# %%
# %matplotlib inline

# %%
results = sim.Simulation(cars_per_km=30, seconds=120, road_length=1000).run()
results = np.array(results)
locations = results[:,:,1]
speeds = results[:,:,0]

# %%
fig = plt.figure(figsize=(12, 6))
for x in locations.swapaxes(0,1):
    plt.scatter(x, np.arange(len(locations)), marker=".")
    
plt.show()

# %%
speeds[-1]
# Out:
# array([22, 22, 18, 16, 18, 18, 18, 26, 28, 30, 32, 34, 34, 30, 30, 32, 34,
#        34, 34, 34, 34, 34, 34, 34, 34, 16, 16, 20, 22, 22])

# %%
speeds.mean()
# Out:
# 29.198611111111113

# %%
locations[-4:-1]
# Out:
# array([[738, 768, 806, 829, 845, 861, 877, 901, 923, 947, 973,   1,  31,
#          79, 116, 148, 180, 214, 248, 282, 332, 366, 452, 500, 536, 594,
#         630, 664, 680, 704],
#        [760, 790, 822, 845, 861, 877, 895, 923, 947, 973,   1,  31,  63,
#         111, 146, 180, 214, 248, 282, 316, 366, 400, 486, 534, 570, 628,
#         660, 680, 698, 722],
#        [784, 810, 840, 861, 877, 895, 915, 947, 973,   1,  31,  63,  97,
#         143, 178, 214, 246, 280, 316, 350, 400, 434, 520, 566, 602, 660,
#         678, 698, 718, 742]])

# %%
imp.reload(sim)
imp.reload(simcar)
# Out:
# <module 'traffic.car' from '/Users/clinton/src/github.com/cndreisbach/traffic-simulation/traffic/car.py'>

# %%
trials = sim.run_trials()

# %%
trials.mean()
# Out:
# 23.591466666666669
